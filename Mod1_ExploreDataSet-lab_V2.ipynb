# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Lab: Exploring the Dataset**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data exploration is the initial phase of data analysis where we aim to understand the data's characteristics, identify patterns, and uncover potential insights. It is a crucial step that helps us make informed decisions about subsequent analysis.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# -   Summarize the key characteristics of a dataset.
# -   Identify different data types commonly used in data analysis.

# %% [markdown]
# ### Install the required library

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ## Load the dataset

# %% [markdown]
# <h3>Read Data</h3>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files.
# </p>

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"

# %% [markdown]
# Utilize the Pandas method read_csv() to load the data into a dataframe.

# %%
df = pd.read_csv(file_path)

# %% [markdown]
# # Hands on Lab

# %% [markdown]
# ## Explore the dataset

# %% [markdown]
# It is a good idea to print the top 5 rows of the dataset to get a feel of how the dataset will look.

# %% [markdown]
# Display the top 5 rows and columns from your dataset.

# %%
## Write your code here
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ## Find out the number of rows and columns

# %% [markdown]
# Start by exploring the numbers of rows and columns of data in the dataset.

# %% [markdown]
# Print the number of rows in the dataset.

# %%
## Write your code here
print(df.shape[0])
# Out:
# 65457

# %% [markdown]
# Print the number of columns in the dataset.

# %%
## Write your code here
print(df.shape[1])
# Out:
# 114

# %% [markdown]
# ## Identify the data types of each column

# %% [markdown]
# Explore the dataset and identify the data types of each column.

# %% [markdown]
# Print the datatype of all columns.

# %%
## Write your code here
with pd.option_context('display.max_rows', 200):
    print(df.dtypes)
# Out:
# ResponseId                          int64
# MainBranch                         object
# Age                                object
# Employment                         object
# RemoteWork                         object
# Check                              object
# CodingActivities                   object
# EdLevel                            object
# LearnCode                          object
# LearnCodeOnline                    object
# TechDoc                            object
# YearsCode                          object
# YearsCodePro                       object
# DevType                            object
# OrgSize                            object
# PurchaseInfluence                  object
# BuyNewTool                         object
# BuildvsBuy                         object
# TechEndorse                        object
# Country                            object
# Currency                           object
# CompTotal                         float64
# ...

# %% [markdown]
# Print the mean age of the survey participants.

# %%
## Write your code here
df_cleaned = df.drop_duplicates()
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), object(100)
# memory usage: 57.4+ MB

# %%
# number of responses in various age groups
num = df_cleaned.groupby('Age')['Age'].value_counts()
num
# Out:
# Age
# 18-24 years old       14098
# 25-34 years old       23911
# 35-44 years old       14942
# 45-54 years old        6249
# 55-64 years old        2575
# 65 years or older       772
# Prefer not to say       322
# Under 18 years old     2568
# Name: count, dtype: int64

# %%
# number of responses with age indicated
counts = num.drop(ages.index[6])
print(f"Participants in age groups\n{counts}")
total = counts.sum()
print("Total participants:", total)
# Out:
# Participants in age groups
# Age
# 18-24 years old       14098
# 25-34 years old       23911
# 35-44 years old       14942
# 45-54 years old        6249
# 55-64 years old        2575
# 65 years or older       772
# Under 18 years old     2568
# Name: count, dtype: int64
# Total participants: 65115

# %%
# mean age of the various age groups: assuming age range is 9-85
#mean_ages = pd.Series([(18+24)/2, (25+34)/2, (35+44)/2, (45+54)/2, (55+64)/2, (65+85)/2, (9+18)/2])
# mean age of the various age groups: assuming age range is 9-89
#mean_ages = pd.Series([(18+24)/2, (25+34)/2, (35+44)/2, (45+54)/2, (55+64)/2, (65+89)/2, (9+18)/2])
# mean age of the various age groups: assuming age range is 9-75
mean_ages = pd.Series([(18+24)/2, (25+34)/2, (35+44)/2, (45+54)/2, (55+64)/2, (65+75)/2, (9+18)/2])
print(f"Mean ages of age groups\n{mean_ages}")
# Out:
# Mean ages of age groups
# 0    21.0
# 1    29.5
# 2    39.5
# 3    49.5
# 4    59.5
# 5    70.0
# 6    13.5
# dtype: float64

# %%
# calculate the weighted mean
val = (counts.values * mean_ages.values).sum()/total
print(f"The overall mean age of the survey participants: {val:.1f}")
# Out:
# The overall mean age of the survey participants: 32.9

# %% [markdown]
# The dataset is the result of a world wide survey. Print how many unique countries are there in the Country column.

# %%
## Write your code here
print("Number of unique countries: ", df['Country'].nunique())
# Out:
# Number of unique countries:  185

# %%
# sort the countries in order of number of survey participants
with pd.option_context('display.max_rows', 200):
    print(df_cleaned.groupby('Country')['Country'].value_counts().sort_values(ascending=False))
# Out:
# Country
# United States of America                                11095
# Germany                                                  4947
# India                                                    4231
# United Kingdom of Great Britain and Northern Ireland     3224
# Ukraine                                                  2672
# France                                                   2110
# Canada                                                   2104
# Poland                                                   1534
# Netherlands                                              1449
# Brazil                                                   1375
# Italy                                                    1341
# Australia                                                1260
# Spain                                                    1123
# Sweden                                                   1016
# Russian Federation                                        925
# ...

# %% [markdown]
# Copyright ©  IBM Corporation. All rights reserved.
