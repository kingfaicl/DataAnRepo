# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
#!wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
#df = pd.read_csv("survey-data.csv")
df = pd.read_csv("df_str_replaced.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
#    Unnamed: 0  ResponseId                      MainBranch                 Age  \
# 0           0           1  I am a developer by profession  Under 18 years old
# 1           1           2  I am a developer by profession     35-44 years old
# 2           2           3  I am a developer by profession     45-54 years old
# 3           3           4           I am learning to code     18-24 years old
# 4           4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
sorted_series = df['DatabaseWantToWorkWith'].str.get_dummies(sep=';').sum().sort_values(ascending=False)
sorted_series
# Out:
# PostgreSQL                    24005
# SQLite                        13489
# MySQL                         12269
# MongoDB                       10982
# Redis                         10847
# Microsoft SQL Server           7905
# Elasticsearch                  6246
# MariaDB                        5947
# Dynamodb                       3503
# Supabase                       2930
# Oracle                         2636
# BigQuery                       2554
# Firebase Realtime Database     2536
# Cassandra                      2399
# Cloud Firestore                2119
# Snowflake                      1784
# Cosmos DB                      1764
# Neo4J                          1570
# DuckDB                         1468
# Clickhouse                     1328
# Databricks SQL                 1218
# Cockroachdb                    1157
# InfluxDB                       1090
# H2                             1040
# Microsoft Access                662
# Couch DB                        620
# ...

# %%
##Write your code here
top5 = sorted_series.head()
plt.pie(top5, labels=top5.index, autopct='%1.1f%%')
plt.title('Top 5 Databases Respondents Want to Work With')
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
sorted_series = df['DevType'].value_counts().sort_values(ascending=False)
sorted_series
# Out:
# DevType
# Developer, full-stack                            18260
# Developer, back-end                               9928
# Student                                           5102
# Developer, front-end                              3349
# Developer, desktop or enterprise applications     2493
# Other (please specify):                           2458
# Developer, mobile                                 2021
# Developer, embedded applications or devices       1623
# Engineering manager                               1275
# Academic researcher                               1238
# Data engineer                                     1118
# Data scientist or machine learning specialist     1024
# DevOps specialist                                 1019
# Research & Development role                        943
# Senior Executive (C-Suite, VP, etc.)               837
# Developer, game or graphics                        706
# Cloud infrastructure engineer                      634
# ...

# %%
##Write your code here
top5 = sorted_series.head()
plt.pie(top5, labels=top5.index, autopct='%1.1f%%')
plt.title('Top 5 Developer Roles')
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
sorted_series = df['OpSysProfessional use'].str.get_dummies(sep=';').sum().sort_values(ascending=False)
sorted_series
# Out:
# Windows                              27918
# MacOS                                18625
# Ubuntu                               16237
# Windows Subsystem for Linux (WSL)     9859
# Debian                                5327
# Android                               4931
# Other Linux-based                     4697
# iOS                                   4280
# Red Hat                               2858
# Arch                                  2521
# Fedora                                1935
# iPadOS                                1562
# Other (please specify):               1209
# ChromeOS                               689
# Cygwin                                 581
# BSD                                    403
# AIX                                    292
# Solaris                                233
# Haiku                                   86
# dtype: int64

# %%
##Write your code here
top5 = sorted_series.head()
plt.pie(top5, labels=top5.index, autopct='%1.1f%%')
plt.title('Top 5 OS')
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
sorted_series = df['LanguageHaveWorkedWith'].str.get_dummies(sep=';').sum().sort_values(ascending=False)
sorted_series
# Out:
# JavaScript                 37492
# HTML/CSS                   31816
# Python                     30719
# SQL                        30682
# TypeScript                 23150
# Bash/Shell (all shells)    20412
# Java                       18239
# C#                         16318
# C++                        13827
# C                          12184
# PHP                        10951
# PowerShell                  8328
# Go                          8103
# Rust                        7559
# Kotlin                      5665
# Lua                         3728
# Dart                        3594
# Assembly                    3233
# Ruby                        3147
# Swift                       2829
# R                           2595
# Visual Basic (.Net)         2499
# MATLAB                      2378
# VBA                         2248
# Groovy                      2004
# Scala                       1547
# Perl                        1482
# GDScript                    1402
# ...

# %%
##Write your code here
top5 = sorted_series.head()
plt.pie(top5, labels=top5.index, autopct='%1.1f%%')
plt.title('Top 5 Most Used Programming Languages')
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
sorted_series = df['NEWCollabToolsHaveWorkedWith'].str.get_dummies(sep=';').sum().sort_values(ascending=False)
sorted_series
# Out:
# Visual Studio Code                  42751
# Visual Studio                       17021
# IntelliJ IDEA                       15555
# Notepad++                           13874
# Vim                                 12523
# Android Studio                       9379
# PyCharm                              8781
# Jupyter Notebook/JupyterLab          7432
# Neovim                               7239
# Sublime Text                         6332
# Eclipse                              5447
# Xcode                                5411
# Nano                                 5364
# WebStorm                             4360
# PhpStorm                             3428
# Rider                                3317
# DataGrip                             2948
# VSCodium                             2807
# IPython                              2732
# CLion                                2695
# Emacs                                2446
# Goland                               1893
# ...

# %%
##Write your code here
top5 = sorted_series.head()
plt.pie(top5, labels=top5.index, autopct='%1.1f%%')
plt.title('Top 5 Collab Tools')
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
df[].value_counts()
# Out:
# LanguageAdmired
# Python                                                                                         1555
# HTML/CSS;JavaScript;TypeScript                                                                 1058
# C#                                                                                              892
# Python;SQL                                                                                      669
# Java                                                                                            583
#                                                                                                ...
# Bash/Shell (all shells);C;HTML/CSS;Java;Lisp;Perl;Python                                          1
# C#;Dart;Go;JavaScript;Python                                                                      1
# JavaScript;PHP;Rust;SQL;TypeScript                                                                1
# ...

# %%
##Write your code here
sorted_series = df['LanguageAdmired'].str.get_dummies(sep=';').sum().sort_values(ascending=False)
print(sorted_series)
top5 = sorted_series.head()
plt.pie(top5, labels=top5.index, autopct='%1.1f%%')
plt.title('Top 5 Most Admired Programming Languages')
plt.show()
# Out:
# JavaScript                 21869
# Python                     20774
# SQL                        20692
# HTML/CSS                   19851
# TypeScript                 16079
# Bash/Shell (all shells)    12776
# C#                         10458
# Java                        8687
# C++                         7339
# Rust                        6215
# C                           5774
# Go                          5485
# PHP                         4793
# PowerShell                  3603
# Kotlin                      3449
# Dart                        1978
# Lua                         1960
# Swift                       1792
# Ruby                        1576
# Assembly                    1409
# R                           1073
# Elixir                       955
# GDScript                     914
# Scala                        788
# Haskell                      634
# Visual Basic (.Net)          618
# Groovy                       611
# VBA                          559
# ...

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
##Write your code here
sorted_series = df['AIToolCurrently Using'].str.get_dummies(sep=';').sum().sort_values(ascending=False)
print(sorted_series)
top5 = sorted_series.head()
plt.pie(top5, labels=top5.index, autopct='%1.1f%%')
plt.title('Top 5 Uses of AI Tools')
plt.show()
# Out:
# Writing code                            29486
# Search for answers                      24295
# Debugging and getting help              20404
# Documenting code                        14439
# Generating content or synthetic data    12538
# Learning about a codebase               11105
# Testing code                             9787
# Committing and reviewing code            4756
# Project planning                         4381
# Predictive analytics                     1888
# Deployment and monitoring                1603
# Other (please specify):                   449
# dtype: int64

# %%
sorted_series = df['AISearchDevHaveWorkedWith'].str.get_dummies(sep=';').sum().sort_values(ascending=False)
print(sorted_series)
top5 = sorted_series.head()
plt.pie(top5, labels=top5.index, autopct='%1.1f%%')
plt.title('Top 5 AI Tools Developers Have Worked With')
plt.show()
# Out:
# ChatGPT                      37923
# GitHub Copilot               19032
# Google Gemini                11056
# Bing AI                       7305
# Visual Studio Intellicode     6296
# Claude                        3760
# Codeium                       2809
# WolframAlpha                  2567
# Perplexity AI                 2462
# Tabnine                       2331
# Phind                         1759
# Meta AI                       1472
# Amazon Q                      1202
# You.com                        625
# Cody                           610
# OpenAI Codex                   599
# Whispr AI                      476
# Quora Poe                      433
# Snyk Code                      392
# Replit Ghostwriter             191
# Lightning AI                   158
# AskCodi                        130
# Andi                           112
# Neeva AI                        82
# Metaphor                        76
# dtype: int64

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here
sorted_series = df['WebframeWantToWorkWith'].str.get_dummies(sep=';').sum().sort_values(ascending=False)
print(sorted_series)
top5 = sorted_series.head()
plt.pie(top5, labels=top5.index, autopct='%1.1f%%')
plt.title('Top 5 Web Frameworks Developers Want to Work With')
plt.show()
# Out:
# React             15404
# Node.js           14735
# Next.js            8507
# Vue.js             7604
# ASP.NET CORE       6905
# Angular            6364
# Express            5616
# Svelte             5374
# Spring Boot        5068
# Django             4973
# FastAPI            4914
# jQuery             4233
# Htmx               4201
# Flask              3994
# ASP.NET            3246
# Laravel            3103
# NestJS             3055
# Blazor             2971
# WordPress          2516
# Ruby on Rails      2301
# Astro              2271
# Nuxt.js            2208
# Deno               1951
# AngularJS          1835
# Solid.js           1684
# Phoenix            1586
# Remix              1294
# Symfony            1153
# Fastify            1127
# Strapi              692
# Elm                 614
# Gatsby              465
# Drupal              418
# CodeIgniter         349
# Play Framework      282
# Yii 2               244
# dtype: int64

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
##Write your code here
sorted_series = df['EmbeddedWantToWorkWith'].str.get_dummies(sep=';').sum().sort_values(ascending=False)
print(sorted_series)
top5 = sorted_series.head()
plt.pie(top5, labels=top5.index, autopct='%1.1f%%')
plt.title('Top 5 Embedded Technologies Developers Want to Work With')
plt.show()
# Out:
# Rasberry Pi     9792
# Arduino         6482
# GNU GCC         5870
# CMake           4693
# Cargo           4567
# LLVM's Clang    4159
# Ninja           1638
# MSVC            1351
# PlatformIO      1141
# Meson            724
# Catch2           440
# QMake            356
# cppunit          338
# doctest          285
# ZMK              256
# Boost.Test       249
# Micronaut        207
# SCons            180
# build2           131
# CUTE              97
# dtype: int64

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
